# %%
import pandas as pd

# %%
data = pd.read_csv("emma_original_data.csv")

# %%
data
# Out:
#      Date as of First week Last week State                   County name  \
# 0        1/6/21     1/4/20    1/2/21    AK             Anchorage Borough
# 1        1/6/21     1/4/20    1/2/21    AK  Fairbanks North Star Borough
# 2        1/6/21     1/4/20    1/2/21    AK       Kenai Peninsula Borough
# 3        1/6/21     1/4/20    1/2/21    AK     Matanuska-Susitna Borough
# 4        1/6/21     1/4/20    1/2/21    AL                Autauga County
# ...         ...        ...       ...   ...                           ...
# 1860     1/6/21     1/4/20    1/2/21    WY                Laramie County
# 1861     1/6/21     1/4/20    1/2/21    WY                Natrona County
# 1862     1/6/21     1/4/20    1/2/21    WY               Sheridan County
# 1863     1/6/21     1/4/20    1/2/21    WY             Sweetwater County
# 1864     1/6/21     1/4/20    1/2/21    WY               Washakie County
#
#       FIPS County Code Urban Rural Code Deaths involving COVID-19  \
# ...

# %%
import numpy as np

# %%
to_drop = ['Date as of',
          'First week',
          'Last week']
data.drop(to_drop, inplace=True, axis=1)

# %%
data
# Out:
#      State                   County name  FIPS County Code Urban Rural Code  \
# 0       AK             Anchorage Borough              2020     Medium metro
# 1       AK  Fairbanks North Star Borough              2090      Small metro
# 2       AK       Kenai Peninsula Borough              2122          Noncore
# 3       AK     Matanuska-Susitna Borough              2170     Medium metro
# 4       AL                Autauga County              1001     Medium metro
# ...    ...                           ...               ...              ...
# 1860    WY                Laramie County             56021      Small metro
# 1861    WY                Natrona County             56025      Small metro
# 1862    WY               Sheridan County             56033     Micropolitan
# 1863    WY             Sweetwater County             56037     Micropolitan
# 1864    WY               Washakie County             56043          Noncore
#
#      Deaths involving COVID-19 Deaths from All Causes
# ...

# %%
data = data[data.State.isin(['CA','WA','OR'])]

# %%
data
# Out:
#      State         County name  FIPS County Code     Urban Rural Code  \
# 111     CA      Alameda County              6001  Large central metro
# 112     CA       Alpine County              6003                  NaN
# 113     CA       Amador County              6005              Noncore
# 114     CA        Butte County              6007          Small metro
# 115     CA    Calaveras County              6009              Noncore
# ...    ...                 ...               ...                  ...
# 1778    WA    Wahkiakum County             53069                  NaN
# 1779    WA  Walla Walla County             53071          Small metro
# 1780    WA      Whatcom County             53073          Small metro
# 1781    WA      Whitman County             53075         Micropolitan
# 1782    WA       Yakima County             53077          Small metro
#
#      Deaths involving COVID-19 Deaths from All Causes
# 111                        573                 10,908
# ...

# %%
data['Urban Rural Code'].fillna('Not Available', inplace = True)
# Out:
# /Users/emmali/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:4517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
data
# Out:
#      State         County name  FIPS County Code     Urban Rural Code  \
# 111     CA      Alameda County              6001  Large central metro
# 112     CA       Alpine County              6003        Not Available
# 113     CA       Amador County              6005              Noncore
# 114     CA        Butte County              6007          Small metro
# 115     CA    Calaveras County              6009              Noncore
# ...    ...                 ...               ...                  ...
# 1778    WA    Wahkiakum County             53069        Not Available
# 1779    WA  Walla Walla County             53071          Small metro
# 1780    WA      Whatcom County             53073          Small metro
# 1781    WA      Whitman County             53075         Micropolitan
# 1782    WA       Yakima County             53077          Small metro
#
#      Deaths involving COVID-19 Deaths from All Causes
# 111                        573                 10,908
# ...

# %%
data['Deaths from All Causes'].fillna(0, inplace = True)
# Out:
# /Users/emmali/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:4517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
data
# Out:
#      State         County name  FIPS County Code     Urban Rural Code  \
# 111     CA      Alameda County              6001  Large central metro
# 112     CA       Alpine County              6003        Not Available
# 113     CA       Amador County              6005              Noncore
# 114     CA        Butte County              6007          Small metro
# 115     CA    Calaveras County              6009              Noncore
# ...    ...                 ...               ...                  ...
# 1778    WA    Wahkiakum County             53069        Not Available
# 1779    WA  Walla Walla County             53071          Small metro
# 1780    WA      Whatcom County             53073          Small metro
# 1781    WA      Whitman County             53075         Micropolitan
# 1782    WA       Yakima County             53077          Small metro
#
#      Deaths involving COVID-19 Deaths from All Causes
# 111                        573                 10,908
# ...

# %%
data_new = data.rename(columns={'County name':'County'})

# %%
data_new
# Out:
#      State              County  FIPS County Code     Urban Rural Code  \
# 111     CA      Alameda County              6001  Large central metro
# 112     CA       Alpine County              6003        Not Available
# 113     CA       Amador County              6005              Noncore
# 114     CA        Butte County              6007          Small metro
# 115     CA    Calaveras County              6009              Noncore
# ...    ...                 ...               ...                  ...
# 1778    WA    Wahkiakum County             53069        Not Available
# 1779    WA  Walla Walla County             53071          Small metro
# 1780    WA      Whatcom County             53073          Small metro
# 1781    WA      Whitman County             53075         Micropolitan
# 1782    WA       Yakima County             53077          Small metro
#
#      Deaths involving COVID-19 Deaths from All Causes
# 111                        573                 10,908
# ...

# %%
data_new = data.rename(columns={'FIPS County Code':'FIPS_code'})

# %%
data_new = data.rename(columns={'Urban Rural Code':'Urban_Rural_Code'})

# %%
data_new = data.rename(columns={'Death involving COVID-19':'Deaths_COVID'})

# %%
data_new = data.rename(columns={'Death from All Causes':'Deaths_total'})

# %%
data_rename = data
data_rename =data.rename(columns={'County name':'County','FIPS County Code':'FIPS_code','Urban Rural Code':'Urban_Rural_Code','Deaths involving COVID-19':'Deaths_COVID','Deaths from All Causes':'Deaths_total'},inplace=True)
# Out:
# /Users/emmali/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
data_rename

# %%
data
# Out:
#      State              County  FIPS_code     Urban_Rural_Code Deaths_COVID  \
# 111     CA      Alameda County       6001  Large central metro          573
# 112     CA       Alpine County       6003        Not Available            0
# 113     CA       Amador County       6005              Noncore           31
# 114     CA        Butte County       6007          Small metro          101
# 115     CA    Calaveras County       6009              Noncore           12
# ...    ...                 ...        ...                  ...          ...
# 1778    WA    Wahkiakum County      53069        Not Available            0
# 1779    WA  Walla Walla County      53071          Small metro           38
# 1780    WA      Whatcom County      53073          Small metro           63
# 1781    WA      Whitman County      53075         Micropolitan           21
# 1782    WA       Yakima County      53077          Small metro          266
#
#      Deaths_total
# 111        10,908
# ...

# %%
df.to_csv('133_county.csv',header = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-e82557337817> in <module>
# ----> 1 df.to_csv('133_county.csv',header = True)
#
# NameError: name 'df' is not defined

# %%
data.to_csv('133_county.csv',header = True)

# %%
data
# Out:
#      State              County  FIPS_code     Urban_Rural_Code Deaths_COVID  \
# 111     CA      Alameda County       6001  Large central metro          573
# 112     CA       Alpine County       6003        Not Available            0
# 113     CA       Amador County       6005              Noncore           31
# 114     CA        Butte County       6007          Small metro          101
# 115     CA    Calaveras County       6009              Noncore           12
# ...    ...                 ...        ...                  ...          ...
# 1778    WA    Wahkiakum County      53069        Not Available            0
# 1779    WA  Walla Walla County      53071          Small metro           38
# 1780    WA      Whatcom County      53073          Small metro           63
# 1781    WA      Whitman County      53075         Micropolitan           21
# 1782    WA       Yakima County      53077          Small metro          266
#
#      Deaths_total
# 111        10,908
# ...

# %%
data
# Out:
#      State              County  FIPS_code     Urban_Rural_Code Deaths_COVID  \
# 111     CA      Alameda County       6001  Large central metro          573
# 112     CA       Alpine County       6003        Not Available            0
# 113     CA       Amador County       6005              Noncore           31
# 114     CA        Butte County       6007          Small metro          101
# 115     CA    Calaveras County       6009              Noncore           12
# ...    ...                 ...        ...                  ...          ...
# 1778    WA    Wahkiakum County      53069        Not Available            0
# 1779    WA  Walla Walla County      53071          Small metro           38
# 1780    WA      Whatcom County      53073          Small metro           63
# 1781    WA      Whitman County      53075         Micropolitan           21
# 1782    WA       Yakima County      53077          Small metro          266
#
#      Deaths_total
# 111        10,908
# ...

# %%
import pandas as pd

# %%
data
# Out:
#      State              County  FIPS_code     Urban_Rural_Code Deaths_COVID  \
# 111     CA      Alameda County       6001  Large central metro          573
# 112     CA       Alpine County       6003        Not Available            0
# 113     CA       Amador County       6005              Noncore           31
# 114     CA        Butte County       6007          Small metro          101
# 115     CA    Calaveras County       6009              Noncore           12
# ...    ...                 ...        ...                  ...          ...
# 1778    WA    Wahkiakum County      53069        Not Available            0
# 1779    WA  Walla Walla County      53071          Small metro           38
# 1780    WA      Whatcom County      53073          Small metro           63
# 1781    WA      Whitman County      53075         Micropolitan           21
# 1782    WA       Yakima County      53077          Small metro          266
#
#      Deaths_total
# 111        10,908
# ...

# %%
data = pd.read_csv("133_county.csv")

# %%
data
# Out:
#      Unnamed: 0 State              County  FIPS_code     Urban_Rural_Code  \
# 0           111    CA      Alameda County       6001  Large central metro
# 1           112    CA       Alpine County       6003        Not Available
# 2           113    CA       Amador County       6005              Noncore
# 3           114    CA        Butte County       6007          Small metro
# 4           115    CA    Calaveras County       6009              Noncore
# ..          ...   ...                 ...        ...                  ...
# 128        1778    WA    Wahkiakum County      53069        Not Available
# 129        1779    WA  Walla Walla County      53071          Small metro
# 130        1780    WA      Whatcom County      53073          Small metro
# 131        1781    WA      Whitman County      53075         Micropolitan
# 132        1782    WA       Yakima County      53077          Small metro
#
#     Deaths_COVID Deaths_total
# 0            573       10,908
# ...

# %%
to_drop = ['FIPS_code']
data.drop(to_drop, inplace=True, axis=1)

# %%
data
# Out:
#      Unnamed: 0 State              County     Urban_Rural_Code Deaths_COVID  \
# 0           111    CA      Alameda County  Large central metro          573
# 1           112    CA       Alpine County        Not Available            0
# 2           113    CA       Amador County              Noncore           31
# 3           114    CA        Butte County          Small metro          101
# 4           115    CA    Calaveras County              Noncore           12
# ..          ...   ...                 ...                  ...          ...
# 128        1778    WA    Wahkiakum County        Not Available            0
# 129        1779    WA  Walla Walla County          Small metro           38
# 130        1780    WA      Whatcom County          Small metro           63
# 131        1781    WA      Whitman County         Micropolitan           21
# 132        1782    WA       Yakima County          Small metro          266
#
#     Deaths_total
# 0         10,908
# 1              0
# ...

# %%
data.to_csv('133_county_new.csv',header = True)

# %%
import pandas as pd

# %%
data = pd.read_csv("133_county_new.csv")

# %%
data
# Out:
#      Unnamed: 0  Unnamed: 0.1 State              County     Urban_Rural_Code  \
# 0             0           111    CA      Alameda County  Large central metro
# 1             1           112    CA       Alpine County        Not Available
# 2             2           113    CA       Amador County              Noncore
# 3             3           114    CA        Butte County          Small metro
# 4             4           115    CA    Calaveras County              Noncore
# ..          ...           ...   ...                 ...                  ...
# 128         128          1778    WA    Wahkiakum County        Not Available
# 129         129          1779    WA  Walla Walla County          Small metro
# 130         130          1780    WA      Whatcom County          Small metro
# 131         131          1781    WA      Whitman County         Micropolitan
# 132         132          1782    WA       Yakima County          Small metro
#
#     Deaths_COVID Deaths_total
# ...

# %%
to_drop = ['Unnamed: 0.1',
          'Unnamed: 0']
data.drop(to_drop, inplace=True, axis=1)

# %%
data
# Out:
#     State              County     Urban_Rural_Code Deaths_COVID Deaths_total
# 0      CA      Alameda County  Large central metro          573       10,908
# 1      CA       Alpine County        Not Available            0            0
# 2      CA       Amador County              Noncore           31          415
# 3      CA        Butte County          Small metro          101        2,313
# 4      CA    Calaveras County              Noncore           12          385
# ..    ...                 ...                  ...          ...          ...
# 128    WA    Wahkiakum County        Not Available            0            0
# 129    WA  Walla Walla County          Small metro           38          651
# 130    WA      Whatcom County          Small metro           63        1,881
# 131    WA      Whitman County         Micropolitan           21          269
# 132    WA       Yakima County          Small metro          266        2,239
#
# [133 rows x 5 columns]

# %%
data
# Out:
#     State              County     Urban_Rural_Code Deaths_COVID Deaths_total
# 0      CA      Alameda County  Large central metro          573       10,908
# 1      CA       Alpine County        Not Available            0            0
# 2      CA       Amador County              Noncore           31          415
# 3      CA        Butte County          Small metro          101        2,313
# 4      CA    Calaveras County              Noncore           12          385
# ..    ...                 ...                  ...          ...          ...
# 128    WA    Wahkiakum County        Not Available            0            0
# 129    WA  Walla Walla County          Small metro           38          651
# 130    WA      Whatcom County          Small metro           63        1,881
# 131    WA      Whitman County         Micropolitan           21          269
# 132    WA       Yakima County          Small metro          266        2,239
#
# [133 rows x 5 columns]

# %%
data
# Out:
#     State              County     Urban_Rural_Code Deaths_COVID Deaths_total
# 0      CA      Alameda County  Large central metro          573       10,908
# 1      CA       Alpine County        Not Available            0            0
# 2      CA       Amador County              Noncore           31          415
# 3      CA        Butte County          Small metro          101        2,313
# 4      CA    Calaveras County              Noncore           12          385
# ..    ...                 ...                  ...          ...          ...
# 128    WA    Wahkiakum County        Not Available            0            0
# 129    WA  Walla Walla County          Small metro           38          651
# 130    WA      Whatcom County          Small metro           63        1,881
# 131    WA      Whitman County         Micropolitan           21          269
# 132    WA       Yakima County          Small metro          266        2,239
#
# [133 rows x 5 columns]

# %%
data = pd.read_csv("133_county_data.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-40-0e831b608bdc> in <module>
# ----> 1 data = pd.read_csv("133_county_data.csv")
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# ...

# %%
data.to_csv('133_county_data.csv',header = True)

# %%
data
# Out:
#     State              County     Urban_Rural_Code Deaths_COVID Deaths_total
# 0      CA      Alameda County  Large central metro          573       10,908
# 1      CA       Alpine County        Not Available            0            0
# 2      CA       Amador County              Noncore           31          415
# 3      CA        Butte County          Small metro          101        2,313
# 4      CA    Calaveras County              Noncore           12          385
# ..    ...                 ...                  ...          ...          ...
# 128    WA    Wahkiakum County        Not Available            0            0
# 129    WA  Walla Walla County          Small metro           38          651
# 130    WA      Whatcom County          Small metro           63        1,881
# 131    WA      Whitman County         Micropolitan           21          269
# 132    WA       Yakima County          Small metro          266        2,239
#
# [133 rows x 5 columns]

# %%
data = pd.read_csv("133_county_data.csv")

# %%
import pandas as pd

# %%
data = pd.read_csv("133_county_data.csv")

# %%
data
# Out:
#      Unnamed: 0 State              County     Urban_Rural_Code Deaths_COVID  \
# 0             0    CA      Alameda County  Large central metro          573
# 1             1    CA       Alpine County        Not Available            0
# 2             2    CA       Amador County              Noncore           31
# 3             3    CA        Butte County          Small metro          101
# 4             4    CA    Calaveras County              Noncore           12
# ..          ...   ...                 ...                  ...          ...
# 128         128    WA    Wahkiakum County        Not Available            0
# 129         129    WA  Walla Walla County          Small metro           38
# 130         130    WA      Whatcom County          Small metro           63
# 131         131    WA      Whitman County         Micropolitan           21
# 132         132    WA       Yakima County          Small metro          266
#
#     Deaths_total
# 0         10,908
# 1              0
# ...

# %%
data.describe
# Out:
# <bound method NDFrame.describe of      Unnamed: 0 State              County     Urban_Rural_Code Deaths_COVID  \
# 0             0    CA      Alameda County  Large central metro          573
# 1             1    CA       Alpine County        Not Available            0
# 2             2    CA       Amador County              Noncore           31
# 3             3    CA        Butte County          Small metro          101
# 4             4    CA    Calaveras County              Noncore           12
# ..          ...   ...                 ...                  ...          ...
# 128         128    WA    Wahkiakum County        Not Available            0
# 129         129    WA  Walla Walla County          Small metro           38
# 130         130    WA      Whatcom County          Small metro           63
# 131         131    WA      Whitman County         Micropolitan           21
# 132         132    WA       Yakima County          Small metro          266
#
#     Deaths_total
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133 entries, 0 to 132
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        133 non-null    int64
#  1   State             133 non-null    object
#  2   County            133 non-null    object
#  3   Urban_Rural_Code  133 non-null    object
#  4   Deaths_COVID      133 non-null    object
#  5   Deaths_total      133 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 6.4+ KB

# %%
data
# Out:
#      Unnamed: 0 State              County     Urban_Rural_Code Deaths_COVID  \
# 0             0    CA      Alameda County  Large central metro          573
# 1             1    CA       Alpine County        Not Available            0
# 2             2    CA       Amador County              Noncore           31
# 3             3    CA        Butte County          Small metro          101
# 4             4    CA    Calaveras County              Noncore           12
# ..          ...   ...                 ...                  ...          ...
# 128         128    WA    Wahkiakum County        Not Available            0
# 129         129    WA  Walla Walla County          Small metro           38
# 130         130    WA      Whatcom County          Small metro           63
# 131         131    WA      Whitman County         Micropolitan           21
# 132         132    WA       Yakima County          Small metro          266
#
#     Deaths_total
# 0         10,908
# 1              0
# ...

# %%
to_drop = ['Unnamed: 0']
data.drop(to_drop, inplace=True, axis=1)

# %%
data
# Out:
#     State              County     Urban_Rural_Code Deaths_COVID Deaths_total
# 0      CA      Alameda County  Large central metro          573       10,908
# 1      CA       Alpine County        Not Available            0            0
# 2      CA       Amador County              Noncore           31          415
# 3      CA        Butte County          Small metro          101        2,313
# 4      CA    Calaveras County              Noncore           12          385
# ..    ...                 ...                  ...          ...          ...
# 128    WA    Wahkiakum County        Not Available            0            0
# 129    WA  Walla Walla County          Small metro           38          651
# 130    WA      Whatcom County          Small metro           63        1,881
# 131    WA      Whitman County         Micropolitan           21          269
# 132    WA       Yakima County          Small metro          266        2,239
#
# [133 rows x 5 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133 entries, 0 to 132
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   State             133 non-null    object
#  1   County            133 non-null    object
#  2   Urban_Rural_Code  133 non-null    object
#  3   Deaths_COVID      133 non-null    object
#  4   Deaths_total      133 non-null    object
# dtypes: object(5)
# memory usage: 5.3+ KB

# %%
data[data.iloc[:,3:].isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [State, County, Urban_Rural_Code, Deaths_COVID, Deaths_total]
# Index: []

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133 entries, 0 to 132
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   State             133 non-null    object
#  1   County            133 non-null    object
#  2   Urban_Rural_Code  133 non-null    object
#  3   Deaths_COVID      133 non-null    object
#  4   Deaths_total      133 non-null    object
# dtypes: object(5)
# memory usage: 5.3+ KB

# %%
data
# Out:
#     State              County     Urban_Rural_Code Deaths_COVID Deaths_total
# 0      CA      Alameda County  Large central metro          573       10,908
# 1      CA       Alpine County        Not Available            0            0
# 2      CA       Amador County              Noncore           31          415
# 3      CA        Butte County          Small metro          101        2,313
# 4      CA    Calaveras County              Noncore           12          385
# ..    ...                 ...                  ...          ...          ...
# 128    WA    Wahkiakum County        Not Available            0            0
# 129    WA  Walla Walla County          Small metro           38          651
# 130    WA      Whatcom County          Small metro           63        1,881
# 131    WA      Whitman County         Micropolitan           21          269
# 132    WA       Yakima County          Small metro          266        2,239
#
# [133 rows x 5 columns]

# %%
data_change = data.copy()

# %%
data_change['State','County','Urban_Rural_Code'] = data_change['State','County','Urban_Rural_Code'].astype('category')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('State', 'County', 'Urban_Rural_Code')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
data_change
# Out:
#     State              County     Urban_Rural_Code Deaths_COVID Deaths_total
# 0      CA      Alameda County  Large central metro          573       10,908
# 1      CA       Alpine County        Not Available            0            0
# 2      CA       Amador County              Noncore           31          415
# 3      CA        Butte County          Small metro          101        2,313
# 4      CA    Calaveras County              Noncore           12          385
# ..    ...                 ...                  ...          ...          ...
# 128    WA    Wahkiakum County        Not Available            0            0
# 129    WA  Walla Walla County          Small metro           38          651
# 130    WA      Whatcom County          Small metro           63        1,881
# 131    WA      Whitman County         Micropolitan           21          269
# 132    WA       Yakima County          Small metro          266        2,239
#
# [133 rows x 5 columns]

# %%
data_change[State,County,Urban_Rural_Code] = data_change[State,County,Urban_Rural_Code'].astype('category')
# Out:
#   File "<ipython-input-59-2fac3f299e77>", line 1
#     data_change[State,County,Urban_Rural_Code] = data_change[State,County,Urban_Rural_Code'].astype('category')
#                                                                                           ^
# SyntaxError: invalid syntax

# %%
data_change
# Out:
#     State              County     Urban_Rural_Code Deaths_COVID Deaths_total
# 0      CA      Alameda County  Large central metro          573       10,908
# 1      CA       Alpine County        Not Available            0            0
# 2      CA       Amador County              Noncore           31          415
# 3      CA        Butte County          Small metro          101        2,313
# 4      CA    Calaveras County              Noncore           12          385
# ..    ...                 ...                  ...          ...          ...
# 128    WA    Wahkiakum County        Not Available            0            0
# 129    WA  Walla Walla County          Small metro           38          651
# 130    WA      Whatcom County          Small metro           63        1,881
# 131    WA      Whitman County         Micropolitan           21          269
# 132    WA       Yakima County          Small metro          266        2,239
#
# [133 rows x 5 columns]

# %%
data_change['Deaths_COVID'] = data_change.Death_COVID.covert_objects(covert_numeric=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-61-a9d0b2941173> in <module>
# ----> 1 data_change['Deaths_COVID'] = data_change.Death_COVID.covert_objects(covert_numeric=True)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Death_COVID'

# %%
data_change
# Out:
#     State              County     Urban_Rural_Code Deaths_COVID Deaths_total
# 0      CA      Alameda County  Large central metro          573       10,908
# 1      CA       Alpine County        Not Available            0            0
# 2      CA       Amador County              Noncore           31          415
# 3      CA        Butte County          Small metro          101        2,313
# 4      CA    Calaveras County              Noncore           12          385
# ..    ...                 ...                  ...          ...          ...
# 128    WA    Wahkiakum County        Not Available            0            0
# 129    WA  Walla Walla County          Small metro           38          651
# 130    WA      Whatcom County          Small metro           63        1,881
# 131    WA      Whitman County         Micropolitan           21          269
# 132    WA       Yakima County          Small metro          266        2,239
#
# [133 rows x 5 columns]

# %%
data_change.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133 entries, 0 to 132
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   State             133 non-null    object
#  1   County            133 non-null    object
#  2   Urban_Rural_Code  133 non-null    object
#  3   Deaths_COVID      133 non-null    object
#  4   Deaths_total      133 non-null    object
# dtypes: object(5)
# memory usage: 5.3+ KB

# %%
data_change["Deaths_COVID"] = pd.to_numeric(data_change.Deaths_COVID, errors='coerce')

# %%
data_change
# Out:
#     State              County     Urban_Rural_Code  Deaths_COVID Deaths_total
# 0      CA      Alameda County  Large central metro         573.0       10,908
# 1      CA       Alpine County        Not Available           0.0            0
# 2      CA       Amador County              Noncore          31.0          415
# 3      CA        Butte County          Small metro         101.0        2,313
# 4      CA    Calaveras County              Noncore          12.0          385
# ..    ...                 ...                  ...           ...          ...
# 128    WA    Wahkiakum County        Not Available           0.0            0
# 129    WA  Walla Walla County          Small metro          38.0          651
# 130    WA      Whatcom County          Small metro          63.0        1,881
# 131    WA      Whitman County         Micropolitan          21.0          269
# 132    WA       Yakima County          Small metro         266.0        2,239
#
# [133 rows x 5 columns]

# %%
data_change.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133 entries, 0 to 132
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   State             133 non-null    object
#  1   County            133 non-null    object
#  2   Urban_Rural_Code  133 non-null    object
#  3   Deaths_COVID      128 non-null    float64
#  4   Deaths_total      133 non-null    object
# dtypes: float64(1), object(4)
# memory usage: 5.3+ KB

# %%
data_change
# Out:
#     State              County     Urban_Rural_Code  Deaths_COVID Deaths_total
# 0      CA      Alameda County  Large central metro         573.0       10,908
# 1      CA       Alpine County        Not Available           0.0            0
# 2      CA       Amador County              Noncore          31.0          415
# 3      CA        Butte County          Small metro         101.0        2,313
# 4      CA    Calaveras County              Noncore          12.0          385
# ..    ...                 ...                  ...           ...          ...
# 128    WA    Wahkiakum County        Not Available           0.0            0
# 129    WA  Walla Walla County          Small metro          38.0          651
# 130    WA      Whatcom County          Small metro          63.0        1,881
# 131    WA      Whitman County         Micropolitan          21.0          269
# 132    WA       Yakima County          Small metro         266.0        2,239
#
# [133 rows x 5 columns]

# %%
data
# Out:
#     State              County     Urban_Rural_Code Deaths_COVID Deaths_total
# 0      CA      Alameda County  Large central metro          573       10,908
# 1      CA       Alpine County        Not Available            0            0
# 2      CA       Amador County              Noncore           31          415
# 3      CA        Butte County          Small metro          101        2,313
# 4      CA    Calaveras County              Noncore           12          385
# ..    ...                 ...                  ...          ...          ...
# 128    WA    Wahkiakum County        Not Available            0            0
# 129    WA  Walla Walla County          Small metro           38          651
# 130    WA      Whatcom County          Small metro           63        1,881
# 131    WA      Whitman County         Micropolitan           21          269
# 132    WA       Yakima County          Small metro          266        2,239
#
# [133 rows x 5 columns]

# %%
data_change2 = data.copy()

# %%
data_change2
# Out:
#     State              County     Urban_Rural_Code Deaths_COVID Deaths_total
# 0      CA      Alameda County  Large central metro          573       10,908
# 1      CA       Alpine County        Not Available            0            0
# 2      CA       Amador County              Noncore           31          415
# 3      CA        Butte County          Small metro          101        2,313
# 4      CA    Calaveras County              Noncore           12          385
# ..    ...                 ...                  ...          ...          ...
# 128    WA    Wahkiakum County        Not Available            0            0
# 129    WA  Walla Walla County          Small metro           38          651
# 130    WA      Whatcom County          Small metro           63        1,881
# 131    WA      Whitman County         Micropolitan           21          269
# 132    WA       Yakima County          Small metro          266        2,239
#
# [133 rows x 5 columns]

# %%
data_change2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133 entries, 0 to 132
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   State             133 non-null    object
#  1   County            133 non-null    object
#  2   Urban_Rural_Code  133 non-null    object
#  3   Deaths_COVID      133 non-null    object
#  4   Deaths_total      133 non-null    object
# dtypes: object(5)
# memory usage: 5.3+ KB

# %%
data_change2["Deaths_COVID"] = pd.to_numeric(data_change2.Deaths_COVID)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "8,034"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-900cd491efc0> in <module>
# ----> 1 data_change2["Deaths_COVID"] = pd.to_numeric(data_change2.Deaths_COVID)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     150         coerce_numeric = errors not in ("ignore", "raise")
#     151         try:
# --> 152             values = lib.maybe_convert_numeric(
#     153                 values, set(), coerce_numeric=coerce_numeric
#     154             )
#
# pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ...

# %%
data_change2["Deaths_total"] = pd.to_numeric(data_change2.Deaths_total)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "10,908"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-73-e9485ebdac7f> in <module>
# ----> 1 data_change2["Deaths_total"] = pd.to_numeric(data_change2.Deaths_total)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     150         coerce_numeric = errors not in ("ignore", "raise")
#     151         try:
# --> 152             values = lib.maybe_convert_numeric(
#     153                 values, set(), coerce_numeric=coerce_numeric
#     154             )
#
# pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ...

# %%
data_change2
# Out:
#     State              County     Urban_Rural_Code Deaths_COVID Deaths_total
# 0      CA      Alameda County  Large central metro          573       10,908
# 1      CA       Alpine County        Not Available            0            0
# 2      CA       Amador County              Noncore           31          415
# 3      CA        Butte County          Small metro          101        2,313
# 4      CA    Calaveras County              Noncore           12          385
# ..    ...                 ...                  ...          ...          ...
# 128    WA    Wahkiakum County        Not Available            0            0
# 129    WA  Walla Walla County          Small metro           38          651
# 130    WA      Whatcom County          Small metro           63        1,881
# 131    WA      Whitman County         Micropolitan           21          269
# 132    WA       Yakima County          Small metro          266        2,239
#
# [133 rows x 5 columns]

# %%
data_change2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133 entries, 0 to 132
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   State             133 non-null    object
#  1   County            133 non-null    object
#  2   Urban_Rural_Code  133 non-null    object
#  3   Deaths_COVID      133 non-null    object
#  4   Deaths_total      133 non-null    object
# dtypes: object(5)
# memory usage: 5.3+ KB

# %%
int(data_change2.replace(',',''))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-76-2bd75770dd31> in <module>
# ----> 1 int(data_change2.replace(',',''))
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'DataFrame'

# %%
data_change3 = data.copy()

# %%
data_change3
# Out:
#     State              County     Urban_Rural_Code Deaths_COVID Deaths_total
# 0      CA      Alameda County  Large central metro          573       10,908
# 1      CA       Alpine County        Not Available            0            0
# 2      CA       Amador County              Noncore           31          415
# 3      CA        Butte County          Small metro          101        2,313
# 4      CA    Calaveras County              Noncore           12          385
# ..    ...                 ...                  ...          ...          ...
# 128    WA    Wahkiakum County        Not Available            0            0
# 129    WA  Walla Walla County          Small metro           38          651
# 130    WA      Whatcom County          Small metro           63        1,881
# 131    WA      Whitman County         Micropolitan           21          269
# 132    WA       Yakima County          Small metro          266        2,239
#
# [133 rows x 5 columns]

# %%
int(data_change3.replace(',','')
# Out:
#   File "<ipython-input-79-d2212db2c9d8>", line 1
#     int(data_change3.replace(',','')
#                                     ^
# SyntaxError: unexpected EOF while parsing

# %%
import pandas as pd

# %%
data = pd.read_csv("133_county_data.csv")

# %%
data
# Out:
#      Unnamed: 0 State              County     Urban_Rural_Code Deaths_COVID  \
# 0             0    CA      Alameda County  Large central metro          573
# 1             1    CA       Alpine County        Not Available            0
# 2             2    CA       Amador County              Noncore           31
# 3             3    CA        Butte County          Small metro          101
# 4             4    CA    Calaveras County              Noncore           12
# ..          ...   ...                 ...                  ...          ...
# 128         128    WA    Wahkiakum County        Not Available            0
# 129         129    WA  Walla Walla County          Small metro           38
# 130         130    WA      Whatcom County          Small metro           63
# 131         131    WA      Whitman County         Micropolitan           21
# 132         132    WA       Yakima County          Small metro          266
#
#     Deaths_total
# 0         10,908
# 1              0
# ...

# %%
to_drop = ['Unnamed: 0']
data.drop(to_drop, inplace=True, axis=1)

# %%
data
# Out:
#     State              County     Urban_Rural_Code Deaths_COVID Deaths_total
# 0      CA      Alameda County  Large central metro          573       10,908
# 1      CA       Alpine County        Not Available            0            0
# 2      CA       Amador County              Noncore           31          415
# 3      CA        Butte County          Small metro          101        2,313
# 4      CA    Calaveras County              Noncore           12          385
# ..    ...                 ...                  ...          ...          ...
# 128    WA    Wahkiakum County        Not Available            0            0
# 129    WA  Walla Walla County          Small metro           38          651
# 130    WA      Whatcom County          Small metro           63        1,881
# 131    WA      Whitman County         Micropolitan           21          269
# 132    WA       Yakima County          Small metro          266        2,239
#
# [133 rows x 5 columns]

# %%
data['County'] = data['County'].str.replace('County', '')

# %%
data
# Out:
#     State        County     Urban_Rural_Code Deaths_COVID Deaths_total
# 0      CA      Alameda   Large central metro          573       10,908
# 1      CA       Alpine         Not Available            0            0
# 2      CA       Amador               Noncore           31          415
# 3      CA        Butte           Small metro          101        2,313
# 4      CA    Calaveras               Noncore           12          385
# ..    ...           ...                  ...          ...          ...
# 128    WA    Wahkiakum         Not Available            0            0
# 129    WA  Walla Walla           Small metro           38          651
# 130    WA      Whatcom           Small metro           63        1,881
# 131    WA      Whitman          Micropolitan           21          269
# 132    WA       Yakima           Small metro          266        2,239
#
# [133 rows x 5 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133 entries, 0 to 132
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   State             133 non-null    object
#  1   County            133 non-null    object
#  2   Urban_Rural_Code  133 non-null    object
#  3   Deaths_COVID      133 non-null    object
#  4   Deaths_total      133 non-null    object
# dtypes: object(5)
# memory usage: 5.3+ KB

# %%
data['Urban_Rural_Code'] = data['Urban_Rural_Code'].str.replace('Not Available', 'NaN')

# %%
data
# Out:
#     State        County     Urban_Rural_Code Deaths_COVID Deaths_total
# 0      CA      Alameda   Large central metro          573       10,908
# 1      CA       Alpine                   NaN            0            0
# 2      CA       Amador               Noncore           31          415
# 3      CA        Butte           Small metro          101        2,313
# 4      CA    Calaveras               Noncore           12          385
# ..    ...           ...                  ...          ...          ...
# 128    WA    Wahkiakum                   NaN            0            0
# 129    WA  Walla Walla           Small metro           38          651
# 130    WA      Whatcom           Small metro           63        1,881
# 131    WA      Whitman          Micropolitan           21          269
# 132    WA       Yakima           Small metro          266        2,239
#
# [133 rows x 5 columns]

# %%
data.to_csv('emma_data_COVID_death.csv',header=True, index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-417e46803cc4> in <module>
# ----> 1 data.to_csv('emma_data_COVID_death.csv',header=True, index=False)
#
# NameError: name 'data' is not defined

# %%
import pandas as pd
data = pd.read_csv("emma_data_COVID_death.csv")

# %%
data
# Out:
#      Unnamed: 0 State        County     Urban_Rural_Code Deaths_COVID  \
# 0             0    CA      Alameda   Large central metro          573
# 1             1    CA       Alpine                   NaN            0
# 2             2    CA       Amador               Noncore           31
# 3             3    CA        Butte           Small metro          101
# 4             4    CA    Calaveras               Noncore           12
# ..          ...   ...           ...                  ...          ...
# 128         128    WA    Wahkiakum                   NaN            0
# 129         129    WA  Walla Walla           Small metro           38
# 130         130    WA      Whatcom           Small metro           63
# 131         131    WA      Whitman          Micropolitan           21
# 132         132    WA       Yakima           Small metro          266
#
#     Deaths_total
# 0         10,908
# 1              0
# 2            415
# 3          2,313
# 4            385
# ...

# %%
to_drop = ['Unnamed: 0']
data.drop(to_drop, inplace=True, axis=1)

# %%
data
# Out:
#     State        County     Urban_Rural_Code Deaths_COVID Deaths_total
# 0      CA      Alameda   Large central metro          573       10,908
# 1      CA       Alpine                   NaN            0            0
# 2      CA       Amador               Noncore           31          415
# 3      CA        Butte           Small metro          101        2,313
# 4      CA    Calaveras               Noncore           12          385
# ..    ...           ...                  ...          ...          ...
# 128    WA    Wahkiakum                   NaN            0            0
# 129    WA  Walla Walla           Small metro           38          651
# 130    WA      Whatcom           Small metro           63        1,881
# 131    WA      Whitman          Micropolitan           21          269
# 132    WA       Yakima           Small metro          266        2,239
#
# [133 rows x 5 columns]

# %%
data['County'] = data['County'].str.strip()

# %%
data
# Out:
#     State       County     Urban_Rural_Code Deaths_COVID Deaths_total
# 0      CA      Alameda  Large central metro          573       10,908
# 1      CA       Alpine                  NaN            0            0
# 2      CA       Amador              Noncore           31          415
# 3      CA        Butte          Small metro          101        2,313
# 4      CA    Calaveras              Noncore           12          385
# ..    ...          ...                  ...          ...          ...
# 128    WA    Wahkiakum                  NaN            0            0
# 129    WA  Walla Walla          Small metro           38          651
# 130    WA      Whatcom          Small metro           63        1,881
# 131    WA      Whitman         Micropolitan           21          269
# 132    WA       Yakima          Small metro          266        2,239
#
# [133 rows x 5 columns]

# %%
data.to_csv('emma_data.csv',header=True, index=False)
